# %%
from scipy.io.wavfile import read,write

# %%
import matplotlib.pyplot as plt

# %%
rate,data = read('mcrumble.wav')
# Out:
# /usr/lib/python3.6/site-packages/scipy/io/wavfile.py:267: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %%
plt.subplot(411)

# %%
plt.plot(range(len(data)),data)

# %%
plt.subplot(412)

# %%
pltcgram(data, NFFT=1024, overlap=0, Fs=rate)# small window
show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-f19b145dc165> in <module>()
# ----> 1 specgram(data, NFFT=1024, overlap=0, Fs=rate)# small window
#       2 show()
#
# /usr/lib/python3.6/site-packages/matplotlib/pyplot.py in specgram(x, NFFT, Fs, Fc, detrend, window, noverlap, cmap, xextent, pad_to, sides, scale_by_freq, mode, scale, vmin, vmax, hold, data, **kwargs)
#    3503                           xextent=xextent, pad_to=pad_to, sides=sides,
#    3504                           scale_by_freq=scale_by_freq, mode=mode, scale=scale,
# -> 3505                           vmin=vmin, vmax=vmax, data=data, **kwargs)
#    3506     finally:
#    3507         ax._hold = washold
#
# /usr/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
# ...

# %%
plt.specgram(data, NFFT=64, noverlap=0, Fs=rate)
plt.show()

# %%
plt.specgram(data, NFFT=128, noverlap=0, Fs=rate, pad_to=512)
plt.show()

# %%
fig = plt.plot(1)

# %%
plt.specgram(data, NFFT=128, noverlap=0, Fs=rate, pad_to=512)
# Out:
# (array([[  1.23935965e+02,   1.23347381e+02,   1.23901651e+02, ...,
#            1.23894521e+02,   1.23049595e+02,   1.23612742e+02],
#         [  2.28883020e+02,   2.27765992e+02,   2.28863793e+02, ...,
#            2.28802329e+02,   2.27232248e+02,   2.28275398e+02],
#         [  1.79504715e+02,   1.78552166e+02,   1.79599383e+02, ...,
#            1.79429051e+02,   1.78173860e+02,   1.79000199e+02],
#         ...,
#         [  8.83812139e-06,   2.59458018e-05,   1.22082521e-06, ...,
#            6.87272705e-06,   4.03166920e-06,   3.02860297e-06],
#         [  1.17280297e-05,   3.10040278e-05,   2.34895896e-06, ...,
#            6.61389158e-06,   2.20177090e-06,   1.06573242e-06],
#         [  6.42497313e-06,   1.63992726e-05,   1.42856008e-06, ...,
#            3.29881180e-06,   7.47279858e-07,   1.94799954e-07]]),
#  array([    0.      ,    21.734375,    43.46875 ,    65.203125,
#            86.9375  ,   108.671875,   130.40625 ,   152.140625,
# ...

# %%
plt.show()

# %%
plt.savefig('hello.pdf')

# %%
plt.specgram(data, NFFT=128, noverlap=0, Fs=rate, pad_to=512)
# Out:
# (array([[  1.23935965e+02,   1.23347381e+02,   1.23901651e+02, ...,
#            1.23894521e+02,   1.23049595e+02,   1.23612742e+02],
#         [  2.28883020e+02,   2.27765992e+02,   2.28863793e+02, ...,
#            2.28802329e+02,   2.27232248e+02,   2.28275398e+02],
#         [  1.79504715e+02,   1.78552166e+02,   1.79599383e+02, ...,
#            1.79429051e+02,   1.78173860e+02,   1.79000199e+02],
#         ...,
#         [  8.83812139e-06,   2.59458018e-05,   1.22082521e-06, ...,
#            6.87272705e-06,   4.03166920e-06,   3.02860297e-06],
#         [  1.17280297e-05,   3.10040278e-05,   2.34895896e-06, ...,
#            6.61389158e-06,   2.20177090e-06,   1.06573242e-06],
#         [  6.42497313e-06,   1.63992726e-05,   1.42856008e-06, ...,
#            3.29881180e-06,   7.47279858e-07,   1.94799954e-07]]),
#  array([    0.      ,    21.734375,    43.46875 ,    65.203125,
#            86.9375  ,   108.671875,   130.40625 ,   152.140625,
# ...

# %%
import scipy.io.wavfile

# %%
wave = read('test.wav')

# %%
    rate, data = read('mcrumble.wav')
# Out:
# /usr/lib/python3.6/site-packages/scipy/io/wavfile.py:267: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %%
data.flatten()
# Out:
# array([128, 128, 128, ..., 128, 128, 128], dtype=uint8)

# %%
plt.specgram(data.flatten())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-121-ffb4a10947ac> in <module>()
# ----> 1 plt.specgram(data.flatten())
#
# /usr/lib/python3.6/site-packages/matplotlib/pyplot.py in specgram(x, NFFT, Fs, Fc, detrend, window, noverlap, cmap, xextent, pad_to, sides, scale_by_freq, mode, scale, vmin, vmax, hold, data, **kwargs)
#    3503                           xextent=xextent, pad_to=pad_to, sides=sides,
#    3504                           scale_by_freq=scale_by_freq, mode=mode, scale=scale,
# -> 3505                           vmin=vmin, vmax=vmax, data=data, **kwargs)
#    3506     finally:
#    3507         ax._hold = washold
#
# /usr/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
# ...
